# %%
# !python main.py --model_arch MBR_4G --config ./config/config_Veri776_windows.yaml
# Out:
#   Config used:
#
# ...

# %%
# !nvidia-smi
# Out:
# Wed Jun  3 02:09:52 2026
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.161.08             Driver Version: 535.161.08   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A40                     On  | 00000000:25:00.0 Off |                    0 |
# |  0%   30C    P8              23W / 300W |      0MiB / 46068MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import psutil
ram = psutil.virtual_memory()
print(f"Total RAM: {ram.total / 1e9:.1f} GB")
print(f"Available RAM: {ram.available / 1e9:.1f} GB")
# Out:
# Total RAM: 541.0 GB
# Available RAM: 512.1 GB

# %%
# !cat /sys/fs/cgroup/memory/memory.limit_in_bytes
# Out:
# 4294967296

# %%
import socket
print(socket.gethostname())
# Out:
# reid-0

# %%
import socket
print(socket.gethostbyname(socket.gethostname()))
# Out:
# 10.233.111.35

# %%
# Run this in Jupyter notebook
# !whoami
# !id
# Out:
# root
# uid=0(root) gid=0(root) groups=0(root),1337

# %%
# !echo $((32 * 1024 * 1024 * 1024)) > /sys/fs/cgroup/memory/memory.limit_in_bytes
# Out:
# /bin/bash: /sys/fs/cgroup/memory/memory.limit_in_bytes: Read-only file system

# %%
# !cat /sys/fs/cgroup/memory/memory.limit_in_bytes
# Out:
# 4294967296

# %%
# Initialize git in your project directory
# !git init
# !git add main.py processor.py models/ config/
# !git commit -m "Backup ReID project files"

# Link to your private GitHub repo and push
# !git remote add origin https://github.com/randallsojm/ReID.git
# !git branch -M main
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /home/jovyan/vehicle_reid_itsc2023/.git/
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@reid-0.(none)')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/IPython/utils/_process_posix.py:148, in ProcessHandler.system(self, cmd)
#     147 else:
# --> 148     child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     149 flush = sys.stdout.flush
#
# ...

# %%
gitignore_content = """
# Dataset (too large for GitHub)
dataset/
*.pem

# Python
__pycache__/
*.pyc
*.pyo
.ipynb_checkpoints/

# Model weights & logs
*.pth
*.pt
logs/
runs/

# System
.DS_Store
"""

with open('.gitignore', 'w') as f:
    f.write(gitignore_content)

print("Created .gitignore")
# Out:
# Created .gitignore

# %%
# !git add .
# !git commit -m "Initial commit - ReID training pipeline"
# !git remote add origin https://github.com/randallsojm/ReID.git
# !git push -u origin main --progress
# Out:
# On branch main
# nothing to commit, working tree clean
# Username for 'https://github.com':

# %%
# !git remote remove origin
